# %%
import numpy as np
import pandas as pd
import scipy as sci
import os, glob
'''
Read the station infomation and event information to rotate it from ZNE to ZRT coordinates
Reference: Plešinger, A., M. Hellweg and D. Seidl, Interactive high-resolution polarization analysis of broadband seismograms.
J. Geophysics, 59, p. 129-139, 1986.

'''
def read_cwb_pandas(filepath,filename):
    import pandas as pd
    from pyproj import Geod
    '''
    read the cwb format using pandas and trigger output
    * Input file_path and file_name
    * Output: Baz, dataframe for ZNE
    '''
    # Capture the station coordinate from cwb header
    # # Capture the station coordinate from cwb header
    file = open(filepath+filename, 'r')
    Lines = file.readlines()[0:16]
    file.close()
    # station codes
    sta_nm=Lines[0].split(" ")[-1].split("\n")[0]
    sta_lat=float(Lines[1].split(" ")[-1])
    sta_lon=float(Lines[2].split(" ")[-1])
    # event codes
    evt_lat=float(Lines[3].split(" ")[-1])
    evt_lon=float(Lines[4].split(" ")[-1])
    # Calculate the azimuthal and distance
    g = Geod(ellps='WGS84')
    az,baz,dist = g.inv(sta_lon,sta_lat,evt_lon,evt_lat)
    # Now get the data
    data = pd.read_csv(filepath+filename,
                       skiprows=16,
                       delim_whitespace=True,
                       names=("time","Z","N","E"),
                      )
    return data,baz,Lines
    # 
def rotate_data(data,baz):
    import numpy as numpy
    import pandas as pd
    '''
    rotate the seismogram with input backazimuthal angle
    replace the N and E colunms by R and T
    '''
    data["R"]=-data["N"]*np.cos(np.radians(baz)) - data["E"]*np.sin(np.radians(baz));
    data["T"]=data["N"]*np.sin(np.radians(baz)) - data["E"]*np.cos(np.radians(baz));
    maxR=data["R"].max();
    minR=data["R"].min();
    maxT=data["R"].max();
    minT=data["R"].min();
    new_data = data.drop(columns=['N', 'E'])
    return new_data,maxR,minR,maxT,minT
    #
def write_csv(filepath,filename,header,data,maxR,minR,maxT,minT):
    f = open(filepath+"/"+filename,"w")
    for i in range(12):
        f.write(header[i])
    f.write('%AmplitudeMAX. R:{:7.4f}~{:7.4f}\n'.format(maxR, minR))
    f.write('%AmplitudeMAX. T:{:7.4f}~{:7.4f}\n'.format(maxT, minT))
    f.write("%DataSequence: Time U(+); R(+), T(+)\n")
    f.write('%Data: 4F10.3\n')
    #
    for i in range(len(data["time"])):
        f.write('%10.3f%10.3f%10.3f%10.3f\n'%(data.iloc[i]["time"],data.iloc[i]["Z"],data.iloc[i]["R"],data.iloc[i]["T"]))
    f.close()
    return
# ============================================================================================================
indir="tsmip_record_April3"
#
outdir=f"{indir}_ZRT"
# ============================================================================================================
#
if not os.path.isdir(outdir):
        os.makedirs(outdir)
# Now check the input directory
for fullfile in glob.glob(f"{indir}/*.cwb"):
    print(fullfile)
    filepath=""
    for i in [len(fullfile.split("/"))-2]:
        filepath=filepath+fullfile.split("/")[i]+"/"
    filename=fullfile.split("/")[-1]
    # print(filepath,filename)
    # 
    data,baz,headers = read_cwb_pandas(filepath,filename)
    new_data,maxR,minR,maxT,minT = rotate_data(data,baz)
    write_csv(outdir,filename,headers,data,maxR,minR,maxT,minT)
print("done!")
# Out:
# tsmip_record_April3/A054_20220917134117_100.0hz.cwb
# tsmip_record_April3/A061_20220917134117_100.0hz.cwb
# tsmip_record_April3/A049_20220917134117_100.0hz.cwb
# tsmip_record_April3/A024_20240403001125_100.0hz.cwb
# tsmip_record_April3/A077_20240403001125_100.0hz.cwb
# tsmip_record_April3/A004_20240402235811_100.0hz.cwb
# tsmip_record_April3/A043_20240403001125_100.0hz.cwb
# tsmip_record_April3/A076_20220918064413_100.0hz.cwb
# tsmip_record_April3/A082_20240403001125_100.0hz.cwb
# tsmip_record_April3/A032_20220917134117_100.0hz.cwb
# tsmip_record_April3/A128_20240402235811_100.0hz.cwb
# tsmip_record_April3/A061_20240403001125_100.0hz.cwb
# tsmip_record_April3/A082_20240402235811_100.0hz.cwb
# tsmip_record_April3/A124_20240403001125_100.0hz.cwb
# tsmip_record_April3/A134_20220918064413_100.0hz.cwb
# tsmip_record_April3/A057_20220917134117_100.0hz.cwb
# tsmip_record_April3/A084_20220918064413_100.0hz.cwb
# tsmip_record_April3/A002_20220918064413_100.0hz.cwb
# tsmip_record_April3/A107_20220917134117_100.0hz.cwb
# tsmip_record_April3/A071_20240402235811_100.0hz.cwb
# tsmip_record_April3/A008_20240402235811_100.0hz.cwb
# tsmip_record_April3/A052_20220918064413_100.0hz.cwb
# tsmip_record_April3/A039_20220917134117_100.0hz.cwb
# tsmip_record_April3/A007_20220917134117_100.0hz.cwb
# tsmip_record_April3/A063_20220918064413_100.0hz.cwb
# tsmip_record_April3/A057_20240402235811_100.0hz.cwb
# tsmip_record_April3/A034_20220918064413_100.0hz.cwb
# tsmip_record_April3/A050_20220917134117_100.0hz.cwb
# tsmip_record_April3/A085_20220917134117_100.0hz.cwb
# tsmip_record_April3/A141_20240402235811_100.0hz.cwb
# tsmip_record_April3/A077_20220917134117_100.0hz.cwb
# tsmip_record_April3/A065_20240402235811_100.0hz.cwb
# tsmip_record_April3/A127_20240402235811_100.0hz.cwb
# tsmip_record_April3/A051_20240403001125_100.0hz.cwb
# tsmip_record_April3/A130_20240402235811_100.0hz.cwb
# tsmip_record_April3/A002_20240402235811_100.0hz.cwb
# tsmip_record_April3/A083_20220918064413_100.0hz.cwb
# tsmip_record_April3/A066_20240403001125_100.0hz.cwb
# tsmip_record_April3/A053_20240403001125_100.0hz.cwb
# tsmip_record_April3/A112_20240403001125_100.0hz.cwb
# tsmip_record_April3/A070_20240402235811_100.0hz.cwb
# tsmip_record_April3/A026_20220917134117_100.0hz.cwb
# tsmip_record_April3/A077_20240402235811_100.0hz.cwb
# tsmip_record_April3/A030_20240403001125_100.0hz.cwb
# tsmip_record_April3/A085_20220918064413_100.0hz.cwb
# tsmip_record_April3/A103_20220918064413_100.0hz.cwb
# tsmip_record_April3/A043_20220917134117_100.0hz.cwb
# tsmip_record_April3/A103_20220917134117_100.0hz.cwb
# tsmip_record_April3/A115_20220917134117_100.0hz.cwb
# tsmip_record_April3/A051_20220917134117_100.0hz.cwb
# tsmip_record_April3/A063_20240402235811_100.0hz.cwb
# tsmip_record_April3/A011_20240403001125_100.0hz.cwb
# tsmip_record_April3/A007_20220918064413_100.0hz.cwb
# tsmip_record_April3/A015_20220918064413_100.0hz.cwb
# tsmip_record_April3/A124_20220917134117_100.0hz.cwb
# tsmip_record_April3/A063_20220917134117_100.0hz.cwb
# tsmip_record_April3/A079_20220917134117_100.0hz.cwb
# tsmip_record_April3/A138_20240403001125_100.0hz.cwb
# tsmip_record_April3/A076_20240403001125_100.0hz.cwb
# tsmip_record_April3/A072_20240402235811_100.0hz.cwb
# tsmip_record_April3/A038_20240402235811_100.0hz.cwb
# tsmip_record_April3/A065_20240403001125_100.0hz.cwb
# tsmip_record_April3/A072_20240403001125_100.0hz.cwb
# tsmip_record_April3/A006_20240403001125_100.0hz.cwb
# tsmip_record_April3/A002_20240403001125_100.0hz.cwb
# tsmip_record_April3/A008_20220918064413_100.0hz.cwb
# tsmip_record_April3/A115_20240402235811_100.0hz.cwb
# tsmip_record_April3/A061_20220918064413_100.0hz.cwb
# tsmip_record_April3/A034_20240402235811_100.0hz.cwb
# tsmip_record_April3/A112_20220917134117_100.0hz.cwb
# tsmip_record_April3/A125_20240402235811_100.0hz.cwb
# tsmip_record_April3/A141_20240403001125_100.0hz.cwb
# tsmip_record_April3/A003_20240403001125_100.0hz.cwb
# tsmip_record_April3/A112_20240402235811_100.0hz.cwb
# tsmip_record_April3/A010_20220918064413_100.0hz.cwb
# tsmip_record_April3/A026_20220918064413_100.0hz.cwb
# tsmip_record_April3/A004_20220917134117_100.0hz.cwb
# tsmip_record_April3/A127_20220918064413_100.0hz.cwb
# tsmip_record_April3/A045_20240403001125_100.0hz.cwb
# tsmip_record_April3/A008_20240403001125_100.0hz.cwb
# tsmip_record_April3/A137_20240402235811_100.0hz.cwb
# tsmip_record_April3/A039_20240403001125_100.0hz.cwb
# tsmip_record_April3/A078_20220917134117_100.0hz.cwb
# tsmip_record_April3/A059_20220918064413_100.0hz.cwb
# tsmip_record_April3/A060_20220917134117_100.0hz.cwb
# tsmip_record_April3/A039_20220918064413_100.0hz.cwb
# tsmip_record_April3/A025_20220917134117_100.0hz.cwb
# tsmip_record_April3/A053_20240402235811_100.0hz.cwb
# tsmip_record_April3/A032_20240402235811_100.0hz.cwb
# tsmip_record_April3/A136_20240403001125_100.0hz.cwb
# tsmip_record_April3/A137_20240403001125_100.0hz.cwb
# tsmip_record_April3/A143_20240402235811_100.0hz.cwb
# tsmip_record_April3/A014_20220917134117_100.0hz.cwb
# tsmip_record_April3/A070_20220917134117_100.0hz.cwb
# tsmip_record_April3/A030_20220918064413_100.0hz.cwb
# tsmip_record_April3/A107_20240402235811_100.0hz.cwb
# tsmip_record_April3/A025_20240402235811_100.0hz.cwb
# tsmip_record_April3/A103_20240402235811_100.0hz.cwb
# tsmip_record_April3/A032_20220918064413_100.0hz.cwb
# tsmip_record_April3/A107_20240403001125_100.0hz.cwb
# tsmip_record_April3/A084_20240402235811_100.0hz.cwb
# tsmip_record_April3/A025_20240403001125_100.0hz.cwb
# tsmip_record_April3/A051_20220918064413_100.0hz.cwb
# tsmip_record_April3/A075_20240402235811_100.0hz.cwb
# tsmip_record_April3/A032_20240403001125_100.0hz.cwb
# tsmip_record_April3/A006_20240402235811_100.0hz.cwb
# tsmip_record_April3/A079_20240403001125_100.0hz.cwb
# tsmip_record_April3/A026_20240403001125_100.0hz.cwb
# tsmip_record_April3/A015_20240403001125_100.0hz.cwb
# tsmip_record_April3/A059_20240403001125_100.0hz.cwb
# tsmip_record_April3/A013_20220918064413_100.0hz.cwb
# tsmip_record_April3/A128_20220917134117_100.0hz.cwb
# tsmip_record_April3/A124_20220918064413_100.0hz.cwb
# tsmip_record_April3/A009_20240403001125_100.0hz.cwb
# tsmip_record_April3/A037_20240402235811_100.0hz.cwb
# tsmip_record_April3/A083_20220917134117_100.0hz.cwb
# tsmip_record_April3/A002_20220917134117_100.0hz.cwb
# tsmip_record_April3/A039_20240402235811_100.0hz.cwb
# tsmip_record_April3/A083_20240402235811_100.0hz.cwb
# tsmip_record_April3/A065_20220918064413_100.0hz.cwb
# tsmip_record_April3/A011_20240402235811_100.0hz.cwb
# tsmip_record_April3/A044_20220917134117_100.0hz.cwb
# tsmip_record_April3/A008_20220917134117_100.0hz.cwb
# tsmip_record_April3/A026_20240402235811_100.0hz.cwb
# tsmip_record_April3/A034_20240403001125_100.0hz.cwb
# tsmip_record_April3/A112_20220918064413_100.0hz.cwb
# tsmip_record_April3/A024_20220917134117_100.0hz.cwb
# tsmip_record_April3/A014_20240403001125_100.0hz.cwb
# tsmip_record_April3/A046_20240402235811_100.0hz.cwb
# tsmip_record_April3/A127_20220917134117_100.0hz.cwb
# tsmip_record_April3/A125_20240403001125_100.0hz.cwb
# tsmip_record_April3/A045_20240402235811_100.0hz.cwb
# tsmip_record_April3/A046_20220918064413_100.0hz.cwb
# tsmip_record_April3/A049_20240403001125_100.0hz.cwb
# tsmip_record_April3/A010_20240403001125_100.0hz.cwb
# tsmip_record_April3/A009_20220918064413_100.0hz.cwb
# tsmip_record_April3/A052_20220917134117_100.0hz.cwb
# tsmip_record_April3/A079_20220918064413_100.0hz.cwb
# tsmip_record_April3/A025_20220918064413_100.0hz.cwb
# tsmip_record_April3/A060_20240403001125_100.0hz.cwb
# tsmip_record_April3/A046_20220917134117_100.0hz.cwb
# tsmip_record_April3/A066_20240402235811_100.0hz.cwb
# tsmip_record_April3/A009_20220917134117_100.0hz.cwb
# tsmip_record_April3/A016_20240402235811_100.0hz.cwb
# tsmip_record_April3/A009_20240402235811_100.0hz.cwb
# tsmip_record_April3/A128_20240403001125_100.0hz.cwb
# tsmip_record_April3/A125_20220917134117_100.0hz.cwb
# tsmip_record_April3/A134_20240402235811_100.0hz.cwb
# tsmip_record_April3/A059_20240402235811_100.0hz.cwb
# tsmip_record_April3/A060_20220918064413_100.0hz.cwb
# tsmip_record_April3/A036_20240402235811_100.0hz.cwb
# tsmip_record_April3/A115_20220918064413_100.0hz.cwb
# tsmip_record_April3/A049_20240402235811_100.0hz.cwb
# tsmip_record_April3/A004_20240403001125_100.0hz.cwb
# tsmip_record_April3/A014_20240402235811_100.0hz.cwb
# tsmip_record_April3/A054_20220918064413_100.0hz.cwb
# tsmip_record_April3/A016_20220918064413_100.0hz.cwb
# tsmip_record_April3/A103_20240403001125_100.0hz.cwb
# tsmip_record_April3/A130_20220918064413_100.0hz.cwb
# tsmip_record_April3/A020_20220918064413_100.0hz.cwb
# tsmip_record_April3/A130_20240403001125_100.0hz.cwb
# tsmip_record_April3/A015_20240402235811_100.0hz.cwb
# tsmip_record_April3/A082_20220917134117_100.0hz.cwb
# tsmip_record_April3/A143_20240403001125_100.0hz.cwb
# tsmip_record_April3/A134_20220917134117_100.0hz.cwb
# tsmip_record_April3/A044_20240403001125_100.0hz.cwb
# tsmip_record_April3/A015_20220917134117_100.0hz.cwb
# tsmip_record_April3/A134_20240403001125_100.0hz.cwb
# tsmip_record_April3/A066_20220918064413_100.0hz.cwb
# tsmip_record_April3/A037_20220918064413_100.0hz.cwb
# tsmip_record_April3/A003_20220917134117_100.0hz.cwb
# tsmip_record_April3/A037_20240403001125_100.0hz.cwb
# tsmip_record_April3/A079_20240402235811_100.0hz.cwb
# tsmip_record_April3/A003_20220918064413_100.0hz.cwb
# tsmip_record_April3/A128_20220918064413_100.0hz.cwb
# tsmip_record_April3/A036_20240403001125_100.0hz.cwb
# tsmip_record_April3/A130_20220917134117_100.0hz.cwb
# tsmip_record_April3/A060_20240402235811_100.0hz.cwb
# tsmip_record_April3/A138_20240402235811_100.0hz.cwb
# tsmip_record_April3/A084_20220917134117_100.0hz.cwb
# tsmip_record_April3/A057_20220918064413_100.0hz.cwb
# tsmip_record_April3/A036_20220917134117_100.0hz.cwb
# tsmip_record_April3/A052_20240402235811_100.0hz.cwb
# tsmip_record_April3/A013_20240402235811_100.0hz.cwb
# tsmip_record_April3/A013_20240403001125_100.0hz.cwb
# tsmip_record_April3/A013_20220917134117_100.0hz.cwb
# tsmip_record_April3/A071_20220917134117_100.0hz.cwb
# tsmip_record_April3/A063_20240403001125_100.0hz.cwb
# tsmip_record_April3/A036_20220918064413_100.0hz.cwb
# tsmip_record_April3/A044_20240402235811_100.0hz.cwb
# tsmip_record_April3/A129_20240402235811_100.0hz.cwb
# tsmip_record_April3/A076_20240402235811_100.0hz.cwb
# tsmip_record_April3/A131_20220918064413_100.0hz.cwb
# tsmip_record_April3/A076_20220917134117_100.0hz.cwb
# tsmip_record_April3/A016_20240403001125_100.0hz.cwb
# tsmip_record_April3/A082_20220918064413_100.0hz.cwb
# tsmip_record_April3/A020_20240402235811_100.0hz.cwb
# tsmip_record_April3/A049_20220918064413_100.0hz.cwb
# tsmip_record_April3/A037_20220917134117_100.0hz.cwb
# tsmip_record_April3/A024_20240402235811_100.0hz.cwb
# tsmip_record_April3/A107_20220918064413_100.0hz.cwb
# tsmip_record_April3/A020_20240403001125_100.0hz.cwb
# tsmip_record_April3/A070_20240403001125_100.0hz.cwb
# tsmip_record_April3/A075_20240403001125_100.0hz.cwb
# tsmip_record_April3/A131_20220917134117_100.0hz.cwb
# tsmip_record_April3/A043_20240402235811_100.0hz.cwb
# tsmip_record_April3/A043_20220918064413_100.0hz.cwb
# tsmip_record_April3/A050_20240403001125_100.0hz.cwb
# tsmip_record_April3/A016_20220917134117_100.0hz.cwb
# tsmip_record_April3/A124_20240402235811_100.0hz.cwb
# tsmip_record_April3/A057_20240403001125_100.0hz.cwb
# tsmip_record_April3/A030_20240402235811_100.0hz.cwb
# tsmip_record_April3/A083_20240403001125_100.0hz.cwb
# tsmip_record_April3/A047_20240402235811_100.0hz.cwb
# tsmip_record_April3/A044_20220918064413_100.0hz.cwb
# tsmip_record_April3/A071_20220918064413_100.0hz.cwb
# tsmip_record_April3/A066_20220917134117_100.0hz.cwb
# tsmip_record_April3/A038_20240403001125_100.0hz.cwb
# tsmip_record_April3/A051_20240402235811_100.0hz.cwb
# tsmip_record_April3/A034_20220917134117_100.0hz.cwb
# tsmip_record_April3/A077_20220918064413_100.0hz.cwb
# tsmip_record_April3/A127_20240403001125_100.0hz.cwb
# tsmip_record_April3/A059_20220917134117_100.0hz.cwb
# tsmip_record_April3/A065_20220917134117_100.0hz.cwb
# tsmip_record_April3/A024_20220918064413_100.0hz.cwb
# tsmip_record_April3/A084_20240403001125_100.0hz.cwb
# tsmip_record_April3/A014_20220918064413_100.0hz.cwb
# tsmip_record_April3/A050_20240402235811_100.0hz.cwb
# tsmip_record_April3/A020_20220917134117_100.0hz.cwb
# tsmip_record_April3/A047_20240403001125_100.0hz.cwb
# tsmip_record_April3/A125_20220918064413_100.0hz.cwb
# tsmip_record_April3/A070_20220918064413_100.0hz.cwb
# tsmip_record_April3/A136_20240402235811_100.0hz.cwb
# tsmip_record_April3/A129_20240403001125_100.0hz.cwb
# tsmip_record_April3/A046_20240403001125_100.0hz.cwb
# tsmip_record_April3/A004_20220918064413_100.0hz.cwb
# tsmip_record_April3/A071_20240403001125_100.0hz.cwb
# tsmip_record_April3/A003_20240402235811_100.0hz.cwb
# tsmip_record_April3/A010_20220917134117_100.0hz.cwb
# tsmip_record_April3/A010_20240402235811_100.0hz.cwb
# tsmip_record_April3/A052_20240403001125_100.0hz.cwb
# tsmip_record_April3/A115_20240403001125_100.0hz.cwb
# tsmip_record_April3/A078_20220918064413_100.0hz.cwb
# tsmip_record_April3/A061_20240402235811_100.0hz.cwb
# done!
